# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
import requests
from datetime import datetime

import os
import sys

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"] 
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rio de janeiro
# Processing Record 2 of Set 1 | santa isabel do rio negro
# Processing Record 3 of Set 1 | honiara
# Processing Record 4 of Set 1 | misratah
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | karratha
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | cockburn town
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | tomatlan
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | olafsvik
# Processing Record 21 of Set 1 | kaitangata
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | clyde river
# Processing Record 24 of Set 1 | rio gallegos
# Processing Record 25 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | alice springs
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | flinders
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | kavaratti
# Processing Record 32 of Set 1 | kamina
# Processing Record 33 of Set 1 | dicabisagan
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | abha
# Processing Record 36 of Set 1 | sakakah
# Processing Record 37 of Set 1 | souillac
# Processing Record 38 of Set 1 | nishihara
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | gaeta
# Processing Record 44 of Set 1 | itarema
# Processing Record 45 of Set 1 | mabaruma
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | vestmannaeyjar
# Processing Record 48 of Set 1 | juba
# Processing Record 49 of Set 1 | coquimbo
# Processing Record 50 of Set 1 | broome
# Processing Record 1 of Set 2 | saldanha
# Processing Record 2 of Set 2 | goderich
# Processing Record 3 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | panguna
# Processing Record 6 of Set 2 | camana
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | mwaya
# Processing Record 10 of Set 2 | maragogi
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | megion
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | sorong
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | villeta
# Processing Record 18 of Set 2 | quesnel
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | wilmington
# Processing Record 21 of Set 2 | savannah bight
# Processing Record 22 of Set 2 | norsup
# Processing Record 23 of Set 2 | buraydah
# Processing Record 24 of Set 2 | sisimiut
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | rundu
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | pacific grove
# Processing Record 29 of Set 2 | beringovskiy
# Processing Record 30 of Set 2 | port hardy
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 2 | nassau
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | arkhara
# Processing Record 36 of Set 2 | shambu
# Processing Record 37 of Set 2 | padang
# Processing Record 38 of Set 2 | ahipara
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | urumqi
# Processing Record 41 of Set 2 | maningrida
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | vao
# Processing Record 44 of Set 2 | moyale
# Processing Record 45 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | acajutla
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | vanavara
# Processing Record 50 of Set 2 | upernavik
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | kruisfontein
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | port lincoln
# Processing Record 5 of Set 3 | mitzic
# Processing Record 6 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | manokwari
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | adrar
# Processing Record 12 of Set 3 | funehiki
# Processing Record 13 of Set 3 | mudgee
# Processing Record 14 of Set 3 | paamiut
# Processing Record 15 of Set 3 | ihosy
# Processing Record 16 of Set 3 | samarai
# Processing Record 17 of Set 3 | kytlym
# City not found. Skipping...
# Processing Record 18 of Set 3 | dire dawa
# Processing Record 19 of Set 3 | inuvik
# Processing Record 20 of Set 3 | ulaangom
# Processing Record 21 of Set 3 | ola
# Processing Record 22 of Set 3 | tuxpan
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | mirandopolis
# Processing Record 25 of Set 3 | kutum
# Processing Record 26 of Set 3 | sao joao da barra
# Processing Record 27 of Set 3 | petropavlovka
# Processing Record 28 of Set 3 | mackay
# Processing Record 29 of Set 3 | hanna
# Processing Record 30 of Set 3 | ucluelet
# Processing Record 31 of Set 3 | longyearbyen
# Processing Record 32 of Set 3 | waounde
# Processing Record 33 of Set 3 | champerico
# Processing Record 34 of Set 3 | vaini
# Processing Record 35 of Set 3 | labuhan
# Processing Record 36 of Set 3 | victoria
# Processing Record 37 of Set 3 | kulhudhuffushi
# Processing Record 38 of Set 3 | aswan
# Processing Record 39 of Set 3 | salisbury
# Processing Record 40 of Set 3 | cowra
# Processing Record 41 of Set 3 | new norfolk
# Processing Record 42 of Set 3 | georgetown
# Processing Record 43 of Set 3 | hami
# Processing Record 44 of Set 3 | mayo
# Processing Record 45 of Set 3 | sao filipe
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | adre
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | padilla
# Processing Record 50 of Set 3 | dargaville
# Processing Record 1 of Set 4 | laguna
# Processing Record 2 of Set 4 | maniitsoq
# Processing Record 3 of Set 4 | vana-vigala
# Processing Record 4 of Set 4 | guerrero negro
# Processing Record 5 of Set 4 | tessalit
# Processing Record 6 of Set 4 | ribeira grande
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | portland
# Processing Record 9 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 4 | daru
# Processing Record 11 of Set 4 | sawakin
# Processing Record 12 of Set 4 | vardo
# Processing Record 13 of Set 4 | aklavik
# Processing Record 14 of Set 4 | ilulissat
# Processing Record 15 of Set 4 | palmer
# Processing Record 16 of Set 4 | hobart
# Processing Record 17 of Set 4 | bhatkal
# Processing Record 18 of Set 4 | boyuibe
# Processing Record 19 of Set 4 | tacoronte
# Processing Record 20 of Set 4 | beloha
# Processing Record 21 of Set 4 | tupik
# Processing Record 22 of Set 4 | cesis
# Processing Record 23 of Set 4 | mananara
# Processing Record 24 of Set 4 | evans
# Processing Record 25 of Set 4 | codrington
# Processing Record 26 of Set 4 | fairbanks
# Processing Record 27 of Set 4 | auki
# Processing Record 28 of Set 4 | smidovich
# Processing Record 29 of Set 4 | klaksvik
# Processing Record 30 of Set 4 | khadzhalmakhi
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | guilin
# Processing Record 33 of Set 4 | srednekolymsk
# Processing Record 34 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 4 | gardan diwal
# City not found. Skipping...
# Processing Record 36 of Set 4 | kayerkan
# Processing Record 37 of Set 4 | aguia branca
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | lebu
# Processing Record 40 of Set 4 | mar del plata
# Processing Record 41 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 4 | snina
# Processing Record 43 of Set 4 | shahrud
# Processing Record 44 of Set 4 | kodiak
# Processing Record 45 of Set 4 | moses lake
# Processing Record 46 of Set 4 | cabo san lucas
# Processing Record 47 of Set 4 | hovd
# Processing Record 48 of Set 4 | nagato
# Processing Record 49 of Set 4 | grants pass
# Processing Record 50 of Set 4 | birao
# Processing Record 1 of Set 5 | hilo
# Processing Record 2 of Set 5 | jasper
# Processing Record 3 of Set 5 | qafsah
# City not found. Skipping...
# Processing Record 4 of Set 5 | puerto escondido
# Processing Record 5 of Set 5 | hazorasp
# Processing Record 6 of Set 5 | saint-augustin
# Processing Record 7 of Set 5 | concordia
# Processing Record 8 of Set 5 | abashiri
# Processing Record 9 of Set 5 | gladstone
# Processing Record 10 of Set 5 | the valley
# Processing Record 11 of Set 5 | provideniya
# Processing Record 12 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 13 of Set 5 | miranda
# Processing Record 14 of Set 5 | nyagan
# Processing Record 15 of Set 5 | hambantota
# Processing Record 16 of Set 5 | granville
# Processing Record 17 of Set 5 | vilyuysk
# Processing Record 18 of Set 5 | filingue
# Processing Record 19 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 20 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 5 | arraial do cabo
# Processing Record 22 of Set 5 | santa rosa
# Processing Record 23 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 5 | namatanai
# Processing Record 25 of Set 5 | jacqueville
# Processing Record 26 of Set 5 | ixtapa
# Processing Record 27 of Set 5 | kupino
# Processing Record 28 of Set 5 | chokurdakh
# Processing Record 29 of Set 5 | anloga
# Processing Record 30 of Set 5 | mbandaka
# Processing Record 31 of Set 5 | fez
# Processing Record 32 of Set 5 | jumla
# Processing Record 33 of Set 5 | boende
# Processing Record 34 of Set 5 | antofagasta
# Processing Record 35 of Set 5 | tiksi
# Processing Record 36 of Set 5 | yerbogachen
# Processing Record 37 of Set 5 | lavrentiya
# Processing Record 38 of Set 5 | lagoa
# Processing Record 39 of Set 5 | petrolina
# Processing Record 40 of Set 5 | penzance
# Processing Record 41 of Set 5 | solnechnyy
# Processing Record 42 of Set 5 | manoel urbano
# Processing Record 43 of Set 5 | ravar
# Processing Record 44 of Set 5 | nome
# Processing Record 45 of Set 5 | thunder bay
# Processing Record 46 of Set 5 | oksfjord
# Processing Record 47 of Set 5 | pochutla
# Processing Record 48 of Set 5 | chapais
# Processing Record 49 of Set 5 | sulangan
# Processing Record 50 of Set 5 | kedgwick
# Processing Record 1 of Set 6 | barra
# Processing Record 2 of Set 6 | lorengau
# Processing Record 3 of Set 6 | san andres
# Processing Record 4 of Set 6 | akyab
# Processing Record 5 of Set 6 | laela
# Processing Record 6 of Set 6 | anadyr
# Processing Record 7 of Set 6 | jiutai
# Processing Record 8 of Set 6 | sioux lookout
# Processing Record 9 of Set 6 | bogomila
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | kamien pomorski
# Processing Record 12 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 6 | east london
# Processing Record 14 of Set 6 | castro
# Processing Record 15 of Set 6 | waddan
# Processing Record 16 of Set 6 | narrabri
# Processing Record 17 of Set 6 | berdigestyakh
# Processing Record 18 of Set 6 | faya
# Processing Record 19 of Set 6 | thaba-tseka
# Processing Record 20 of Set 6 | oktyabrskoye
# Processing Record 21 of Set 6 | fort nelson
# Processing Record 22 of Set 6 | saint-louis
# Processing Record 23 of Set 6 | jati
# Processing Record 24 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 25 of Set 6 | sagua la grande
# Processing Record 26 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 6 | vaitape
# Processing Record 28 of Set 6 | golden
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | sabancuy
# Processing Record 31 of Set 6 | abalak
# Processing Record 32 of Set 6 | batemans bay
# Processing Record 33 of Set 6 | portalegre
# Processing Record 34 of Set 6 | san quintin
# Processing Record 35 of Set 6 | lithakia
# Processing Record 36 of Set 6 | mount isa
# Processing Record 37 of Set 6 | airai
# Processing Record 38 of Set 6 | krasnozatonskiy
# Processing Record 39 of Set 6 | aksu
# Processing Record 40 of Set 6 | chuy
# Processing Record 41 of Set 6 | durban
# Processing Record 42 of Set 6 | mutoko
# Processing Record 43 of Set 6 | bethel
# Processing Record 44 of Set 6 | port moresby
# Processing Record 45 of Set 6 | qaqortoq
# Processing Record 46 of Set 6 | khandbari
# Processing Record 47 of Set 6 | mana
# Processing Record 48 of Set 6 | reconquista
# Processing Record 49 of Set 6 | belogorsk
# Processing Record 50 of Set 6 | muscat
# Processing Record 1 of Set 7 | lasa
# Processing Record 2 of Set 7 | sandakan
# Processing Record 3 of Set 7 | norman wells
# Processing Record 4 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 7 | marsh harbour
# Processing Record 6 of Set 7 | plettenberg bay
# Processing Record 7 of Set 7 | saint-philippe
# Processing Record 8 of Set 7 | komyshnya
# City not found. Skipping...
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | yeovil
# Processing Record 11 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 7 | goes
# Processing Record 13 of Set 7 | gushikawa
# Processing Record 14 of Set 7 | acapulco
# Processing Record 15 of Set 7 | bengkulu
# Processing Record 16 of Set 7 | kharp
# Processing Record 17 of Set 7 | hamilton
# Processing Record 18 of Set 7 | muzquiz
# City not found. Skipping...
# Processing Record 19 of Set 7 | kaeo
# Processing Record 20 of Set 7 | bertoua
# Processing Record 21 of Set 7 | shenjiamen
# Processing Record 22 of Set 7 | savannakhet
# Processing Record 23 of Set 7 | mogadishu
# Processing Record 24 of Set 7 | luderitz
# Processing Record 25 of Set 7 | naze
# Processing Record 26 of Set 7 | kulu
# Processing Record 27 of Set 7 | samagaltay
# Processing Record 28 of Set 7 | sawankhalok
# Processing Record 29 of Set 7 | kovdor
# Processing Record 30 of Set 7 | vila velha
# Processing Record 31 of Set 7 | apollonia
# Processing Record 32 of Set 7 | tlahualilo
# City not found. Skipping...
# Processing Record 33 of Set 7 | toora-khem
# Processing Record 34 of Set 7 | sibiti
# Processing Record 35 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 7 | san carlos de bariloche
# Processing Record 37 of Set 7 | uyuni
# Processing Record 38 of Set 7 | bondoukou
# Processing Record 39 of Set 7 | warwick
# Processing Record 40 of Set 7 | grindavik
# Processing Record 41 of Set 7 | catuday
# Processing Record 42 of Set 7 | faanui
# Processing Record 43 of Set 7 | caohai
# Processing Record 44 of Set 7 | jinchang
# Processing Record 45 of Set 7 | mbabane
# Processing Record 46 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 7 | port shepstone
# Processing Record 48 of Set 7 | mamakan
# Processing Record 49 of Set 7 | san rafael del sur
# Processing Record 50 of Set 7 | matagami
# Processing Record 1 of Set 8 | alofi
# Processing Record 2 of Set 8 | kindu
# Processing Record 3 of Set 8 | phalaborwa
# Processing Record 4 of Set 8 | amnat charoen
# Processing Record 5 of Set 8 | itarantim
# Processing Record 6 of Set 8 | esperantinopolis
# Processing Record 7 of Set 8 | walvis bay
# Processing Record 8 of Set 8 | pacifica
# Processing Record 9 of Set 8 | onguday
# Processing Record 10 of Set 8 | brooks
# Processing Record 11 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 12 of Set 8 | edson
# Processing Record 13 of Set 8 | anan
# Processing Record 14 of Set 8 | tual
# Processing Record 15 of Set 8 | rocha
# Processing Record 16 of Set 8 | rovaniemi
# Processing Record 17 of Set 8 | yarmouth
# Processing Record 18 of Set 8 | aden
# Processing Record 19 of Set 8 | sinnamary
# Processing Record 20 of Set 8 | fortuna
# Processing Record 21 of Set 8 | bhasawar
# Processing Record 22 of Set 8 | calvinia
# Processing Record 23 of Set 8 | iguape
# Processing Record 24 of Set 8 | taga
# Processing Record 25 of Set 8 | sambrial
# Processing Record 26 of Set 8 | lutkun
# Processing Record 27 of Set 8 | saint george
# Processing Record 28 of Set 8 | beyneu
# Processing Record 29 of Set 8 | kurchum
# Processing Record 30 of Set 8 | leningradskiy
# Processing Record 31 of Set 8 | bud
# Processing Record 32 of Set 8 | merauke
# Processing Record 33 of Set 8 | port macquarie
# Processing Record 34 of Set 8 | nuuk
# Processing Record 35 of Set 8 | marabba
# Processing Record 36 of Set 8 | halacho
# Processing Record 37 of Set 8 | diego de almagro
# Processing Record 38 of Set 8 | beasain
# Processing Record 39 of Set 8 | san luis
# Processing Record 40 of Set 8 | reyes
# Processing Record 41 of Set 8 | yar-sale
# Processing Record 42 of Set 8 | jaguaruna
# Processing Record 43 of Set 8 | bitung
# Processing Record 44 of Set 8 | cayenne
# Processing Record 45 of Set 8 | las cruces
# Processing Record 46 of Set 8 | erice
# Processing Record 47 of Set 8 | provost
# Processing Record 48 of Set 8 | ziro
# Processing Record 49 of Set 8 | saint-joseph
# Processing Record 50 of Set 8 | san cristobal
# Processing Record 1 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 9 | tuatapere
# Processing Record 3 of Set 9 | najran
# Processing Record 4 of Set 9 | praia da vitoria
# Processing Record 5 of Set 9 | manjo
# Processing Record 6 of Set 9 | trincomalee
# Processing Record 7 of Set 9 | weeze
# Processing Record 8 of Set 9 | seguela
# Processing Record 9 of Set 9 | port-cartier
# Processing Record 10 of Set 9 | viedma
# Processing Record 11 of Set 9 | carutapera
# Processing Record 12 of Set 9 | tak
# Processing Record 13 of Set 9 | wanning
# Processing Record 14 of Set 9 | tiarei
# Processing Record 15 of Set 9 | graham
# Processing Record 16 of Set 9 | maltahohe
# Processing Record 17 of Set 9 | cabanas
# Processing Record 18 of Set 9 | san patricio
# Processing Record 19 of Set 9 | tonstad
# Processing Record 20 of Set 9 | husavik
# Processing Record 21 of Set 9 | ancud
# Processing Record 22 of Set 9 | salinopolis
# Processing Record 23 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 9 | winnemucca
# Processing Record 25 of Set 9 | kavieng
# Processing Record 26 of Set 9 | moussoro
# Processing Record 27 of Set 9 | pitsunda
# Processing Record 28 of Set 9 | kudahuvadhoo
# Processing Record 29 of Set 9 | normandin
# Processing Record 30 of Set 9 | irbeyskoye
# Processing Record 31 of Set 9 | maykor
# Processing Record 32 of Set 9 | elliot lake
# Processing Record 33 of Set 9 | coos bay
# Processing Record 34 of Set 9 | haines junction
# Processing Record 35 of Set 9 | starkville
# Processing Record 36 of Set 9 | nampula
# Processing Record 37 of Set 9 | kahului
# Processing Record 38 of Set 9 | parkes
# Processing Record 39 of Set 9 | antalaha
# Processing Record 40 of Set 9 | thoen
# Processing Record 41 of Set 9 | virginia beach
# Processing Record 42 of Set 9 | ailigandi
# Processing Record 43 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 9 | bathsheba
# Processing Record 45 of Set 9 | dunedin
# Processing Record 46 of Set 9 | rosarito
# Processing Record 47 of Set 9 | ughelli
# Processing Record 48 of Set 9 | kampene
# Processing Record 49 of Set 9 | sola
# Processing Record 50 of Set 9 | parabel
# Processing Record 1 of Set 10 | kisangani
# Processing Record 2 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 10 | erenhot
# Processing Record 4 of Set 10 | sangin
# Processing Record 5 of Set 10 | zatyshshya
# Processing Record 6 of Set 10 | roald
# Processing Record 7 of Set 10 | skibbereen
# Processing Record 8 of Set 10 | port blair
# Processing Record 9 of Set 10 | jiayuguan
# Processing Record 10 of Set 10 | praya
# Processing Record 11 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 10 | isangel
# Processing Record 13 of Set 10 | udachnyy
# Processing Record 14 of Set 10 | nanortalik
# Processing Record 15 of Set 10 | karamken
# City not found. Skipping...
# Processing Record 16 of Set 10 | san fernando
# Processing Record 17 of Set 10 | sooke
# Processing Record 18 of Set 10 | tura
# Processing Record 19 of Set 10 | havoysund
# Processing Record 20 of Set 10 | steinbach
# Processing Record 21 of Set 10 | beidao
# Processing Record 22 of Set 10 | khromtau
# Processing Record 23 of Set 10 | sur
# Processing Record 24 of Set 10 | progreso
# Processing Record 25 of Set 10 | taicheng
# Processing Record 26 of Set 10 | poum
# Processing Record 27 of Set 10 | tatawin
# Processing Record 28 of Set 10 | jalu
# Processing Record 29 of Set 10 | gorontalo
# Processing Record 30 of Set 10 | suffern
# Processing Record 31 of Set 10 | slave lake
# Processing Record 32 of Set 10 | camocim
# Processing Record 33 of Set 10 | ulles
# Processing Record 34 of Set 10 | abu samrah
# Processing Record 35 of Set 10 | aleppo
# Processing Record 36 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 37 of Set 10 | ust-tsilma
# Processing Record 38 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 10 | aksarka
# Processing Record 40 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 41 of Set 10 | dicamay
# Processing Record 42 of Set 10 | eldorado
# Processing Record 43 of Set 10 | cedar park
# Processing Record 44 of Set 10 | pitimbu
# Processing Record 45 of Set 10 | bjerkvik
# Processing Record 46 of Set 10 | te anau
# Processing Record 47 of Set 10 | pombia
# Processing Record 48 of Set 10 | bolobo
# Processing Record 49 of Set 10 | xuanzhou
# Processing Record 50 of Set 10 | mayumba
# Processing Record 1 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 11 | yatou
# Processing Record 3 of Set 11 | yeehaw junction
# City not found. Skipping...
# Processing Record 4 of Set 11 | kununurra
# Processing Record 5 of Set 11 | andros
# Processing Record 6 of Set 11 | college
# Processing Record 7 of Set 11 | destin
# Processing Record 8 of Set 11 | benguela
# Processing Record 9 of Set 11 | butembo
# Processing Record 10 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 11 of Set 11 | bac lieu
# Processing Record 12 of Set 11 | roma
# Processing Record 13 of Set 11 | novyy urengoy
# Processing Record 14 of Set 11 | jimenez
# Processing Record 15 of Set 11 | barao de melgaco
# Processing Record 16 of Set 11 | wewak
# Processing Record 17 of Set 11 | kouqian
# Processing Record 18 of Set 11 | krasnoselkup
# Processing Record 19 of Set 11 | grand gaube
# Processing Record 20 of Set 11 | cagliliog
# Processing Record 21 of Set 11 | redding
# Processing Record 22 of Set 11 | culebra
# Processing Record 23 of Set 11 | makarov
# Processing Record 24 of Set 11 | acari
# Processing Record 25 of Set 11 | perelyub
# Processing Record 26 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 11 | kyra
# Processing Record 28 of Set 11 | davila
# Processing Record 29 of Set 11 | pizarro
# Processing Record 30 of Set 11 | meulaboh
# Processing Record 31 of Set 11 | sambava
# Processing Record 32 of Set 11 | navrongo
# Processing Record 33 of Set 11 | melioratorov
# Processing Record 34 of Set 11 | nantucket
# Processing Record 35 of Set 11 | ponta do sol
# Processing Record 36 of Set 11 | mahibadhoo
# Processing Record 37 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 11 | ribeira brava
# Processing Record 39 of Set 11 | balabac
# Processing Record 40 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 41 of Set 11 | ligayan
# Processing Record 42 of Set 11 | mandali
# Processing Record 43 of Set 11 | santa lucia
# Processing Record 44 of Set 11 | illapel
# Processing Record 45 of Set 11 | kyabe
# Processing Record 46 of Set 11 | dingle
# Processing Record 47 of Set 11 | tapiogyorgye
# Processing Record 48 of Set 11 | bridlington
# Processing Record 49 of Set 11 | ostrovnoy
# Processing Record 50 of Set 11 | pandan
# Processing Record 1 of Set 12 | rawson
# Processing Record 2 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 12 | mobaye
# Processing Record 4 of Set 12 | tougue
# Processing Record 5 of Set 12 | nara
# Processing Record 6 of Set 12 | puri
# Processing Record 7 of Set 12 | hobbs
# Processing Record 8 of Set 12 | sete
# Processing Record 9 of Set 12 | beian
# Processing Record 10 of Set 12 | atbasar
# Processing Record 11 of Set 12 | oistins
# Processing Record 12 of Set 12 | kontagora
# Processing Record 13 of Set 12 | bar harbor
# Processing Record 14 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 12 | flin flon
# Processing Record 16 of Set 12 | tyulgan
# Processing Record 17 of Set 12 | callaguip
# Processing Record 18 of Set 12 | ipora
# Processing Record 19 of Set 12 | rio grande
# Processing Record 20 of Set 12 | caraballeda
# Processing Record 21 of Set 12 | mirnyy
# Processing Record 22 of Set 12 | komsomolskiy
# Processing Record 23 of Set 12 | constitucion
# Processing Record 24 of Set 12 | havre
# Processing Record 25 of Set 12 | cururupu
# Processing Record 26 of Set 12 | lompoc
# Processing Record 27 of Set 12 | ankpa
# Processing Record 28 of Set 12 | areosa
# Processing Record 29 of Set 12 | tiznit
# Processing Record 30 of Set 12 | sampit
# Processing Record 31 of Set 12 | bullhead city
# Processing Record 32 of Set 12 | vallenar
# Processing Record 33 of Set 12 | vilcun
# Processing Record 34 of Set 12 | borbon
# Processing Record 35 of Set 12 | gat
# Processing Record 36 of Set 12 | sabang
# Processing Record 37 of Set 12 | natal
# Processing Record 38 of Set 12 | helong
# Processing Record 39 of Set 12 | deputatskiy
# Processing Record 40 of Set 12 | christchurch
# Processing Record 41 of Set 12 | mbulu
# Processing Record 42 of Set 12 | yumen
# Processing Record 43 of Set 12 | sept-iles
# Processing Record 44 of Set 12 | sile
# Processing Record 45 of Set 12 | black forest
# Processing Record 46 of Set 12 | qiongshan
# Processing Record 47 of Set 12 | belyye berega
# Processing Record 48 of Set 12 | altamira
# Processing Record 49 of Set 12 | korla
# Processing Record 50 of Set 12 | latung
# Processing Record 1 of Set 13 | saint-georges
# Processing Record 2 of Set 13 | pratapgarh
# Processing Record 3 of Set 13 | qovlar
# Processing Record 4 of Set 13 | sobreira
# Processing Record 5 of Set 13 | bindi
# Processing Record 6 of Set 13 | saint-francois
# Processing Record 7 of Set 13 | oga
# Processing Record 8 of Set 13 | ust-koksa
# Processing Record 9 of Set 13 | port antonio
# Processing Record 10 of Set 13 | bairiki
# Processing Record 11 of Set 13 | sukheke
# City not found. Skipping...
# Processing Record 12 of Set 13 | portsmouth
# Processing Record 13 of Set 13 | quelimane
# Processing Record 14 of Set 13 | prince albert
# Processing Record 15 of Set 13 | todos santos
# Processing Record 16 of Set 13 | tairua
# Processing Record 17 of Set 13 | ust-nera
# Processing Record 18 of Set 13 | launceston
# Processing Record 19 of Set 13 | nokha
# Processing Record 20 of Set 13 | rodrigues alves
# Processing Record 21 of Set 13 | praia
# Processing Record 22 of Set 13 | dubbo
# Processing Record 23 of Set 13 | badarwas
# Processing Record 24 of Set 13 | prince rupert
# Processing Record 25 of Set 13 | vestmanna
# Processing Record 26 of Set 13 | qostanay
# Processing Record 27 of Set 13 | linqiong
# Processing Record 28 of Set 13 | vagur
# Processing Record 29 of Set 13 | wallacetown
# Processing Record 30 of Set 13 | iskateley
# Processing Record 31 of Set 13 | tucurui
# Processing Record 32 of Set 13 | axim
# Processing Record 33 of Set 13 | mpulungu
# Processing Record 34 of Set 13 | swan hill
# Processing Record 35 of Set 13 | ventspils
# Processing Record 36 of Set 13 | novaya lyada
# Processing Record 37 of Set 13 | rockland
# Processing Record 38 of Set 13 | mahajanga
# Processing Record 39 of Set 13 | besikduzu
# Processing Record 40 of Set 13 | miri
# Processing Record 41 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 42 of Set 13 | ramhormoz
# Processing Record 43 of Set 13 | novobirilyussy
# Processing Record 44 of Set 13 | sembe
# Processing Record 45 of Set 13 | zyryanka
# Processing Record 46 of Set 13 | cherskiy
# Processing Record 47 of Set 13 | kungurtug
# Processing Record 48 of Set 13 | simiti
# Processing Record 49 of Set 13 | moose factory
# Processing Record 50 of Set 13 | ilan
# Processing Record 1 of Set 14 | clonakilty
# Processing Record 2 of Set 14 | jiexiu
# Processing Record 3 of Set 14 | tabou
# Processing Record 4 of Set 14 | villarrobledo
# Processing Record 5 of Set 14 | oropesa
# Processing Record 6 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 14 | marysville
# Processing Record 8 of Set 14 | tocopilla
# Processing Record 9 of Set 14 | half moon bay
# Processing Record 10 of Set 14 | kieta
# Processing Record 11 of Set 14 | clarence town
# Processing Record 12 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 13 of Set 14 | itoman
# Processing Record 14 of Set 14 | coihaique
# Processing Record 15 of Set 14 | boyolangu
# Processing Record 16 of Set 14 | shimonoseki
# Processing Record 17 of Set 14 | san ignacio
# Processing Record 18 of Set 14 | trindade
# Processing Record 19 of Set 14 | olinda
# Processing Record 20 of Set 14 | amurrio
# Processing Record 21 of Set 14 | ransang
# Processing Record 22 of Set 14 | ponta delgada
# Processing Record 23 of Set 14 | yangambi
# Processing Record 24 of Set 14 | troitskiy
# Processing Record 25 of Set 14 | narsaq
# Processing Record 26 of Set 14 | ormara
# Processing Record 27 of Set 14 | thinadhoo
# Processing Record 28 of Set 14 | holme
# Processing Record 29 of Set 14 | victor harbor
# Processing Record 30 of Set 14 | bismarck
# Processing Record 31 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 32 of Set 14 | camacari
# Processing Record 33 of Set 14 | mahuva
# Processing Record 34 of Set 14 | barras
# Processing Record 35 of Set 14 | dauriya
# Processing Record 36 of Set 14 | la cumbre
# Processing Record 37 of Set 14 | omboue
# Processing Record 38 of Set 14 | bishop auckland
# Processing Record 39 of Set 14 | ternate
# Processing Record 40 of Set 14 | taoudenni
# Processing Record 41 of Set 14 | chokwe
# Processing Record 42 of Set 14 | kermanshah
# Processing Record 43 of Set 14 | lipovtsy
# Processing Record 44 of Set 14 | nizhniy chir
# Processing Record 45 of Set 14 | lubao
# Processing Record 46 of Set 14 | cam ranh
# Processing Record 47 of Set 14 | severodvinsk
# Processing Record 48 of Set 14 | tabriz
# Processing Record 49 of Set 14 | labelle
# Processing Record 50 of Set 14 | urucara
# Processing Record 1 of Set 15 | krasnogorsk
# Processing Record 2 of Set 15 | letovice
# Processing Record 3 of Set 15 | marawi
# Processing Record 4 of Set 15 | stromness
# Processing Record 5 of Set 15 | mitsamiouli
# Processing Record 6 of Set 15 | puerto narino
# Processing Record 7 of Set 15 | hobyo
# Processing Record 8 of Set 15 | zarechnyy
# Processing Record 9 of Set 15 | sobolevo
# Processing Record 10 of Set 15 | worthington
# Processing Record 11 of Set 15 | nehe
# Processing Record 12 of Set 15 | ha tinh
# Processing Record 13 of Set 15 | xai-xai
# Processing Record 14 of Set 15 | bo
# City not found. Skipping...
# Processing Record 15 of Set 15 | along
# Processing Record 16 of Set 15 | salalah
# Processing Record 17 of Set 15 | juneau
# Processing Record 18 of Set 15 | asau
# Processing Record 19 of Set 15 | mattru
# Processing Record 20 of Set 15 | mount darwin
# Processing Record 21 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 15 | chicama
# Processing Record 23 of Set 15 | llata
# Processing Record 24 of Set 15 | tecoanapa
# Processing Record 25 of Set 15 | adeje
# Processing Record 26 of Set 15 | shache
# Processing Record 27 of Set 15 | oranjemund
# Processing Record 28 of Set 15 | lagdo
# Processing Record 29 of Set 15 | waitati
# Processing Record 30 of Set 15 | kapoeta
# Processing Record 31 of Set 15 | freetown
# Processing Record 32 of Set 15 | noumea
# Processing Record 33 of Set 15 | damara
# Processing Record 34 of Set 15 | salvador
# Processing Record 35 of Set 15 | teya
# Processing Record 36 of Set 15 | oriximina
# Processing Record 37 of Set 15 | doha
# Processing Record 38 of Set 15 | allen
# Processing Record 39 of Set 15 | santo domingo
# Processing Record 40 of Set 15 | escarcega
# Processing Record 41 of Set 15 | mildura
# Processing Record 42 of Set 15 | teteven
# Processing Record 43 of Set 15 | zeya
# Processing Record 44 of Set 15 | caravelas
# Processing Record 45 of Set 15 | pangnirtung
# Processing Record 46 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 47 of Set 15 | norfolk
# Processing Record 48 of Set 15 | gigmoto
# Processing Record 49 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 15 | hervey bay
# Processing Record 1 of Set 16 | mataram
# Processing Record 2 of Set 16 | mumford
# Processing Record 3 of Set 16 | novikovo
# Processing Record 4 of Set 16 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 16 | cap malheureux
# Processing Record 6 of Set 16 | severnyy
# Processing Record 7 of Set 16 | berlevag
# Processing Record 8 of Set 16 | gurskoye
# City not found. Skipping...
# Processing Record 9 of Set 16 | bucerias
# Processing Record 10 of Set 16 | kiruna
# Processing Record 11 of Set 16 | minas
# Processing Record 12 of Set 16 | zhanaozen
# Processing Record 13 of Set 16 | new iberia
# Processing Record 14 of Set 16 | cabedelo
# Processing Record 15 of Set 16 | kokstad
# Processing Record 16 of Set 16 | atar
# Processing Record 17 of Set 16 | saint anthony
# Processing Record 18 of Set 16 | miyako
# Processing Record 19 of Set 16 | san angelo
# Processing Record 20 of Set 16 | kysyl-syr
# Processing Record 21 of Set 16 | eureka
# Processing Record 22 of Set 16 | broken hill
# Processing Record 23 of Set 16 | rudbar
# Processing Record 24 of Set 16 | sterling
# Processing Record 25 of Set 16 | asayita
# City not found. Skipping...
# Processing Record 26 of Set 16 | bawku
# Processing Record 27 of Set 16 | garowe
# Processing Record 28 of Set 16 | cameta
# Processing Record 29 of Set 16 | kokoda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Rio De Janeiro',
#   'Country': 'BR',
#   'Lat': -22.9,
#   'Lng': -43.21,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 13.87,
#   'Current Description': 'moderate rain'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Country': 'BR',
#   'Lat': -0.41,
#   'Lng': -65.02,
#   'Max Temp': 78.06,
#   'Humidity': 83,
#   'Cloudiness': 83,
#   'Wind Speed': 1.43,
#   'Current Description': 'light rain'},
#  {'City': 'Honiara',
#   'Country': 'SB',
#   'Lat': -9.43,
#   'Lng': 159.95,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds'},
#  {'City': 'Misratah',
#   'Country': 'LY',
#   'Lat': 32.38,
#   'Lng': 15.09,
#   'Max Temp': 82.89,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 8.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 66,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 37.4,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 49.78,
#   'Humidity': 93,
#   'Cloudiness': 84,
#   'Wind Speed': 11.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 54,
#   'Wind Speed': 12.75,
#   'Current Description': 'light rain'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 78.66,
#   'Humidity': 76,
#   'Cloudiness': 8,
#   'Wind Speed': 16.98,
#   'Current Description': 'light rain'},
#  {'City': 'Karratha',
#   'Country': 'AU',
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Max Temp': 64.31,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 11.9,
#   'Current Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 48.27,
#   'Humidity': 57,
#   'Cloudiness': 94,
#   'Wind Speed': 3.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 54,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 1.81,
#   'Current Description': 'fog'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 52,
#   'Humidity': 83,
#   'Cloudiness': 89,
#   'Wind Speed': 13.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cockburn Town',
#   'Country': 'TC',
#   'Lat': 21.46,
#   'Lng': -71.14,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 53.04,
#   'Humidity': 70,
#   'Cloudiness': 64,
#   'Wind Speed': 33.13,
#   'Current Description': 'light rain'},
#  {'City': 'Tomatlan',
#   'Country': 'MX',
#   'Lat': 19.93,
#   'Lng': -105.25,
#   'Max Temp': 77.88,
#   'Humidity': 92,
#   'Cloudiness': 58,
#   'Wind Speed': 2.13,
#   'Current Description': 'moderate rain'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 72,
#   'Humidity': 74,
#   'Cloudiness': 12,
#   'Wind Speed': 4.5,
#   'Current Description': 'light rain'},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Max Temp': 55.67,
#   'Humidity': 80,
#   'Cloudiness': 56,
#   'Wind Speed': 6.4,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 44.01,
#   'Humidity': 70,
#   'Cloudiness': 97,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 55.4,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 17.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.62,
#   'Lng': -69.22,
#   'Max Temp': 35.6,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 23.04,
#   'Current Description': 'light rain'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 44.31,
#   'Humidity': 64,
#   'Cloudiness': 98,
#   'Wind Speed': 3.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alice Springs',
#   'Country': 'AU',
#   'Lat': -23.7,
#   'Lng': 133.88,
#   'Max Temp': 66.2,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 71.94,
#   'Humidity': 74,
#   'Cloudiness': 17,
#   'Wind Speed': 7.4,
#   'Current Description': 'few clouds'},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Lat': -34.58,
#   'Lng': 150.86,
#   'Max Temp': 63,
#   'Humidity': 59,
#   'Cloudiness': 51,
#   'Wind Speed': 8.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 62.6,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 12.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Kavaratti',
#   'Country': 'IN',
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 81.28,
#   'Humidity': 81,
#   'Cloudiness': 94,
#   'Wind Speed': 11.61,
#   'Current Description': 'light rain'},
#  {'City': 'Kamina',
#   'Country': 'CD',
#   'Lat': -8.74,
#   'Lng': 24.99,
#   'Max Temp': 67.15,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 0.76,
#   'Current Description': 'clear sky'},
#  {'City': 'Dicabisagan',
#   'Country': 'PH',
#   'Lat': 17.08,
#   'Lng': 122.42,
#   'Max Temp': 81.34,
#   'Humidity': 79,
#   'Cloudiness': 97,
#   'Wind Speed': 1.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 48.2,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 25.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Abha',
#   'Country': 'SA',
#   'Lat': 18.22,
#   'Lng': 42.51,
#   'Max Temp': 68,
#   'Humidity': 59,
#   'Cloudiness': 97,
#   'Wind Speed': 5.73,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sakakah',
#   'Country': 'SA',
#   'Lat': 29.97,
#   'Lng': 40.21,
#   'Max Temp': 78.8,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 69.8,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds'},
#  {'City': 'Nishihara',
#   'Country': 'JP',
#   'Lat': 26.18,
#   'Lng': 127.76,
#   'Max Temp': 87.8,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 50,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Description': 'moderate rain'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 73.4,
#   'Humidity': 69,
#   'Cloudiness': 35,
#   'Wind Speed': 8.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 43.02,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 7.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gaeta',
#   'Country': 'IT',
#   'Lat': 41.22,
#   'Lng': 13.56,
#   'Max Temp': 73.99,
#   'Humidity': 91,
#   'Cloudiness': 69,
#   'Wind Speed': 4.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Itarema',
#   'Country': 'BR',
#   'Lat': -2.92,
#   'Lng': -39.92,
#   'Max Temp': 78.12,
#   'Humidity': 77,
#   'Cloudiness': 24,
#   'Wind Speed': 16.33,
#   'Current Description': 'few clouds'},
#  {'City': 'Mabaruma',
#   'Country': 'GY',
#   'Lat': 8.2,
#   'Lng': -59.78,
#   'Max Temp': 75.78,
#   'Humidity': 97,
#   'Cloudiness': 88,
#   'Wind Speed': 4.29,
#   'Current Description': 'light rain'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.24,
#   'Lng': 130.99,
#   'Max Temp': 55.4,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 5.19,
#   'Current Description': 'clear sky'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 53.31,
#   'Humidity': 93,
#   'Cloudiness': 98,
#   'Wind Speed': 7.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Juba',
#   'Country': 'SS',
#   'Lat': 4.85,
#   'Lng': 31.58,
#   'Max Temp': 70.03,
#   'Humidity': 91,
#   'Cloudiness': 66,
#   'Wind Speed': 2.42,
#   'Current Description': 'broken clouds'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 51.8,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Broome',
#   'Country': 'US',
#   'Lat': 42.25,
#   'Lng': -75.83,
#   'Max Temp': 73.4,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 46.4,
#   'Humidity': 75,
#   'Cloudiness': 27,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Goderich',
#   'Country': 'CA',
#   'Lat': 43.75,
#   'Lng': -81.72,
#   'Max Temp': 73,
#   'Humidity': 82,
#   'Cloudiness': 62,
#   'Wind Speed': 8.01,
#   'Current Description': 'light rain'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 53.31,
#   'Humidity': 83,
#   'Cloudiness': 94,
#   'Wind Speed': 11.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Panguna',
#   'Country': 'PG',
#   'Lat': -6.32,
#   'Lng': 155.48,
#   'Max Temp': 76.03,
#   'Humidity': 91,
#   'Cloudiness': 37,
#   'Wind Speed': 1.41,
#   'Current Description': 'moderate rain'},
#  {'City': 'Camana',
#   'Country': 'PE',
#   'Lat': -16.62,
#   'Lng': -72.71,
#   'Max Temp': 59.31,
#   'Humidity': 75,
#   'Cloudiness': 73,
#   'Wind Speed': 4.14,
#   'Current Description': 'broken clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 42.8,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 81.95,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 8.55,
#   'Current Description': 'clear sky'},
#  {'City': 'Mwaya',
#   'Country': 'TZ',
#   'Lat': -9.55,
#   'Lng': 33.95,
#   'Max Temp': 70.18,
#   'Humidity': 60,
#   'Cloudiness': 84,
#   'Wind Speed': 2.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Maragogi',
#   'Country': 'BR',
#   'Lat': -9.01,
#   'Lng': -35.22,
#   'Max Temp': 73.71,
#   'Humidity': 85,
#   'Cloudiness': 29,
#   'Wind Speed': 11.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 14.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Megion',
#   'Country': 'RU',
#   'Lat': 61.03,
#   'Lng': 76.11,
#   'Max Temp': 57.2,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 6.71,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 68,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 53.6,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sorong',
#   'Country': 'ID',
#   'Lat': -0.88,
#   'Lng': 131.25,
#   'Max Temp': 78.15,
#   'Humidity': 86,
#   'Cloudiness': 87,
#   'Wind Speed': 11.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 66.99,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Villeta',
#   'Country': 'CO',
#   'Lat': 5.01,
#   'Lng': -74.47,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Quesnel',
#   'Country': 'CA',
#   'Lat': 53,
#   'Lng': -122.5,
#   'Max Temp': 89.6,
#   'Humidity': 21,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Wilmington',
#   'Country': 'US',
#   'Lat': 34.23,
#   'Lng': -77.94,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Savannah Bight',
#   'Country': 'HN',
#   'Lat': 16.45,
#   'Lng': -85.85,
#   'Max Temp': 84.51,
#   'Humidity': 73,
#   'Cloudiness': 59,
#   'Wind Speed': 7.7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Norsup',
#   'Country': 'VU',
#   'Lat': -16.07,
#   'Lng': 167.38,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Buraydah',
#   'Country': 'SA',
#   'Lat': 26.33,
#   'Lng': 43.98,
#   'Max Temp': 84.2,
#   'Humidity': 32,
#   'Cloudiness': 43,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sisimiut',
#   'Country': 'GL',
#   'Lat': 66.94,
#   'Lng': -53.67,
#   'Max Temp': 48.56,
#   'Humidity': 59,
#   'Cloudiness': 53,
#   'Wind Speed': 2.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 35.6,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Current Description': 'shower rain'},
#  {'City': 'Rundu',
#   'Country': 'NA',
#   'Lat': -17.93,
#   'Lng': 19.77,
#   'Max Temp': 59.2,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 0.38,
#   'Current Description': 'clear sky'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 46.99,
#   'Humidity': 82,
#   'Cloudiness': 87,
#   'Wind Speed': 8.01,
#   'Current Description': 'light rain'},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.62,
#   'Lng': -121.92,
#   'Max Temp': 73.4,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'smoke'},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Lat': 63.05,
#   'Lng': 179.32,
#   'Max Temp': 53.2,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 15.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 77,
#   'Humidity': 53,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Nassau',
#   'Country': 'US',
#   'Lat': 40.75,
#   'Lng': -73.58,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 14.99,
#   'Current Description': 'light rain'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 88,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Arkhara',
#   'Country': 'RU',
#   'Lat': 49.42,
#   'Lng': 130.08,
#   'Max Temp': 62.73,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 7.43,
#   'Current Description': 'moderate rain'},
#  {'City': 'Shambu',
#   'Country': 'ET',
#   'Lat': 9.57,
#   'Lng': 37.1,
#   'Max Temp': 52.18,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.25,
#   'Current Description': 'light rain'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.95,
#   'Lng': 100.35,
#   'Max Temp': 77.67,
#   'Humidity': 69,
#   'Cloudiness': 66,
#   'Wind Speed': 3.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.17,
#   'Lng': 173.17,
#   'Max Temp': 59.72,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 17.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 83.46,
#   'Humidity': 75,
#   'Cloudiness': 36,
#   'Wind Speed': 7.4,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Urumqi',
#   'Country': 'CN',
#   'Lat': 43.8,
#   'Lng': 87.6,
#   'Max Temp': 75.2,
#   'Humidity': 31,
#   'Cloudiness': 9,
#   'Wind Speed': 13.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Maningrida',
#   'Country': 'AU',
#   'Lat': -12.07,
#   'Lng': 134.27,
#   'Max Temp': 76.53,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 7.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 50,
#   'Humidity': 100,
#   'Cloudiness': 14,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 69.66,
#   'Humidity': 78,
#   'Cloudiness': 57,
#   'Wind Speed': 15.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Moyale',
#   'Country': 'KE',
#   'Lat': 3.52,
#   'Lng': 39.06,
#   'Max Temp': 65.75,
#   'Humidity': 74,
#   'Cloudiness': 56,
#   'Wind Speed': 8.59,
#   'Current Description': 'broken clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 54.32,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 3.42,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Acajutla',
#   'Country': 'SV',
#   'Lat': 13.59,
#   'Lng': -89.83,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 66.99,
#   'Humidity': 93,
#   'Cloudiness': 89,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vanavara',
#   'Country': 'RU',
#   'Lat': 60.34,
#   'Lng': 102.28,
#   'Max Temp': 52.92,
#   'Humidity': 57,
#   'Cloudiness': 99,
#   'Wind Speed': 6.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 46.4,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 1.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 51.8,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 34.45,
#   'Current Description': 'light rain'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 50,
#   'Humidity': 67,
#   'Cloudiness': 93,
#   'Wind Speed': 11.01,
#   'Current Description': 'light rain'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 69.8,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds'},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Lat': -34.73,
#   'Lng': 135.87,
#   'Max Temp': 56.21,
#   'Humidity': 68,
#   'Cloudiness': 34,
#   'Wind Speed': 22.21,
#   'Current Description': 'light rain'},
#  {'City': 'Mitzic',
#   'Country': 'GA',
#   'Lat': 0.78,
#   'Lng': 11.55,
#   'Max Temp': 69.8,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 4.54,
#   'Current Description': 'light rain'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 39,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Manokwari',
#   'Country': 'ID',
#   'Lat': -0.87,
#   'Lng': 134.08,
#   'Max Temp': 83.53,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Current Description': 'light rain'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 58.28,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 8.88,
#   'Current Description': 'light rain'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 64.4,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5,
#   'Lng': -10.07,
#   'Max Temp': 98.98,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 18.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Funehiki',
#   'Country': 'JP',
#   'Lat': 37.43,
#   'Lng': 140.58,
#   'Max Temp': 82,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Current Description': 'few clouds'},
#  {'City': 'Mudgee',
#   'Country': 'AU',
#   'Lat': -32.59,
#   'Lng': 149.59,
#   'Max Temp': 54,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Paamiut',
#   'Country': 'GL',
#   'Lat': 61.99,
#   'Lng': -49.67,
#   'Max Temp': 48.52,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 10.98,
#   'Current Description': 'clear sky'},
#  {'City': 'Ihosy',
#   'Country': 'MG',
#   'Lat': -22.4,
#   'Lng': 46.12,
#   'Max Temp': 61.57,
#   'Humidity': 84,
#   'Cloudiness': 60,
#   'Wind Speed': 8.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Samarai',
#   'Country': 'PG',
#   'Lat': -10.62,
#   'Lng': 150.67,
#   'Max Temp': 76.26,
#   'Humidity': 59,
#   'Cloudiness': 36,
#   'Wind Speed': 7.54,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dire Dawa',
#   'Country': 'ET',
#   'Lat': 9.59,
#   'Lng': 41.87,
#   'Max Temp': 70.63,
#   'Humidity': 66,
#   'Cloudiness': 79,
#   'Wind Speed': 13.53,
#   'Current Description': 'light rain'},
#  {'City': 'Inuvik',
#   'Country': 'CA',
#   'Lat': 68.35,
#   'Lng': -133.72,
#   'Max Temp': 62.6,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ulaangom',
#   'Country': 'MN',
#   'Lat': 49.98,
#   'Lng': 92.07,
#   'Max Temp': 62.26,
#   'Humidity': 72,
#   'Cloudiness': 5,
#   'Wind Speed': 1.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Ola',
#   'Country': 'RU',
#   'Lat': 59.58,
#   'Lng': 151.28,
#   'Max Temp': 59.18,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 3.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuxpan',
#   'Country': 'MX',
#   'Lat': 19.55,
#   'Lng': -103.4,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 19.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Mirandopolis',
#   'Country': 'BR',
#   'Lat': -21.13,
#   'Lng': -51.1,
#   'Max Temp': 70.27,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 18.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.67,
#   'Max Temp': 69.19,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 9.08,
#   'Current Description': 'light rain'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Max Temp': 73.87,
#   'Humidity': 85,
#   'Cloudiness': 63,
#   'Wind Speed': 19.57,
#   'Current Description': 'broken clouds'},
#  {'City': 'Petropavlovka',
#   'Country': 'RU',
#   'Lat': 50.61,
#   'Lng': 105.32,
#   'Max Temp': 54.81,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 0.31,
#   'Current Description': 'clear sky'},
#  {'City': 'Mackay',
#   'Country': 'AU',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp': 73.99,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Hanna',
#   'Country': 'CA',
#   'Lat': 51.63,
#   'Lng': -111.9,
#   'Max Temp': 84,
#   'Humidity': 42,
#   'Cloudiness': 50,
#   'Wind Speed': 7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ucluelet',
#   'Country': 'CA',
#   'Lat': 48.93,
#   'Lng': -125.55,
#   'Max Temp': 66.99,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Waounde',
#   'Country': 'SN',
#   'Lat': 15.26,
#   'Lng': -12.87,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Champerico',
#   'Country': 'GT',
#   'Lat': 14.3,
#   'Lng': -91.92,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'thunderstorm'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.88,
#   'Lng': 112.21,
#   'Max Temp': 77.59,
#   'Humidity': 78,
#   'Cloudiness': 42,
#   'Wind Speed': 10.49,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 82,
#   'Humidity': 78,
#   'Cloudiness': 91,
#   'Wind Speed': 7.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kulhudhuffushi',
#   'Country': 'MV',
#   'Lat': 6.62,
#   'Lng': 73.07,
#   'Max Temp': 82.44,
#   'Humidity': 75,
#   'Cloudiness': 96,
#   'Wind Speed': 8.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aswan',
#   'Country': 'EG',
#   'Lat': 24.09,
#   'Lng': 32.91,
#   'Max Temp': 90.05,
#   'Humidity': 21,
#   'Cloudiness': 8,
#   'Wind Speed': 13.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Salisbury',
#   'Country': 'GB',
#   'Lat': 51.07,
#   'Lng': -1.8,
#   'Max Temp': 63,
#   'Humidity': 88,
#   'Cloudiness': 92,
#   'Wind Speed': 8.05,
#   'Current Description': 'light rain'},
#  {'City': 'Cowra',
#   'Country': 'AU',
#   'Lat': -33.83,
#   'Lng': 148.68,
#   'Max Temp': 43,
#   'Humidity': 93,
#   'Cloudiness': 74,
#   'Wind Speed': 1.01,
#   'Current Description': 'broken clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 51.01,
#   'Humidity': 90,
#   'Cloudiness': 80,
#   'Wind Speed': 1.86,
#   'Current Description': 'broken clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 75.67,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 9.51,
#   'Current Description': 'clear sky'},
#  {'City': 'Mayo',
#   'Country': 'US',
#   'Lat': 38.89,
#   'Lng': -76.51,
#   'Max Temp': 75,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'moderate rain'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 78.46,
#   'Humidity': 82,
#   'Cloudiness': 59,
#   'Wind Speed': 2.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sitka',
#   'Country': 'US',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'Adre',
#   'Country': 'TD',
#   'Lat': 13.47,
#   'Lng': 22.2,
#   'Max Temp': 75.33,
#   'Humidity': 79,
#   'Cloudiness': 92,
#   'Wind Speed': 2.42,
#   'Current Description': 'light rain'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 88,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Padilla',
#   'Country': 'CO',
#   'Lat': 3.22,
#   'Lng': -76.31,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dargaville',
#   'Country': 'NZ',
#   'Lat': -35.93,
#   'Lng': 173.88,
#   'Max Temp': 59.63,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 15.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Laguna',
#   'Country': 'US',
#   'Lat': 38.42,
#   'Lng': -121.42,
#   'Max Temp': 104,
#   'Humidity': 27,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Maniitsoq',
#   'Country': 'GL',
#   'Lat': 65.42,
#   'Lng': -52.9,
#   'Max Temp': 51.26,
#   'Humidity': 57,
#   'Cloudiness': 32,
#   'Wind Speed': 6.31,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vana-Vigala',
#   'Country': 'EE',
#   'Lat': 58.78,
#   'Lng': 24.25,
#   'Max Temp': 48,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 0.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Max Temp': 81.54,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 18.48,
#   'Current Description': 'clear sky'},
#  {'City': 'Tessalit',
#   'Country': 'ML',
#   'Lat': 20.2,
#   'Lng': 1.01,
#   'Max Temp': 92.26,
#   'Humidity': 36,
#   'Cloudiness': 14,
#   'Wind Speed': 7.83,
#   'Current Description': 'few clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 74.23,
#   'Humidity': 89,
#   'Cloudiness': 91,
#   'Wind Speed': 21.99,
#   'Current Description': 'light rain'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 39.31,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 13.67,
#   'Current Description': 'light rain'},
#  {'City': 'Portland',
#   'Country': 'US',
#   'Lat': 45.52,
#   'Lng': -122.68,
#   'Max Temp': 95,
#   'Humidity': 31,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds'},
#  {'City': 'Daru',
#   'Country': 'PG',
#   'Lat': -9.08,
#   'Lng': 143.21,
#   'Max Temp': 78.39,
#   'Humidity': 71,
#   'Cloudiness': 13,
#   'Wind Speed': 12.15,
#   'Current Description': 'few clouds'},
#  {'City': 'Sawakin',
#   'Country': 'SD',
#   'Lat': 19.11,
#   'Lng': 37.33,
#   'Max Temp': 92.35,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 1.48,
#   'Current Description': 'clear sky'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 47.62,
#   'Humidity': 76,
#   'Cloudiness': 86,
#   'Wind Speed': 14.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 64.4,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Max Temp': 51.8,
#   'Humidity': 43,
#   'Cloudiness': 32,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Description': 'light rain'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 51.01,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bhatkal',
#   'Country': 'IN',
#   'Lat': 13.97,
#   'Lng': 74.57,
#   'Max Temp': 78.24,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 6.35,
#   'Current Description': 'moderate rain'},
#  {'City': 'Boyuibe',
#   'Country': 'BO',
#   'Lat': -20.42,
#   'Lng': -63.28,
#   'Max Temp': 58.66,
#   'Humidity': 74,
#   'Cloudiness': 46,
#   'Wind Speed': 1.21,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tacoronte',
#   'Country': 'ES',
#   'Lat': 28.48,
#   'Lng': -16.41,
#   'Max Temp': 73.99,
#   'Humidity': 52,
#   'Cloudiness': 3,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.17,
#   'Lng': 45.05,
#   'Max Temp': 63.3,
#   'Humidity': 96,
#   'Cloudiness': 25,
#   'Wind Speed': 6.73,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tupik',
#   'Country': 'RU',
#   'Lat': 54.43,
#   'Lng': 119.93,
#   'Max Temp': 50.04,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 7.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Cesis',
#   'Country': 'LV',
#   'Lat': 57.31,
#   'Lng': 25.27,
#   'Max Temp': 54,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mananara',
#   'Country': 'MG',
#   'Lat': -16.17,
#   'Lng': 49.77,
#   'Max Temp': 65.91,
#   'Humidity': 91,
#   'Cloudiness': 22,
#   'Wind Speed': 5.01,
#   'Current Description': 'light rain'},
#  {'City': 'Evans',
#   'Country': 'US',
#   'Lat': 33.53,
#   'Lng': -82.13,
#   'Max Temp': 81,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Current Description': 'very heavy rain'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 51.73,
#   'Humidity': 86,
#   'Cloudiness': 62,
#   'Wind Speed': 12.17,
#   'Current Description': 'broken clouds'},
#  {'City': 'Fairbanks',
#   'Country': 'US',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 70,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Auki',
#   'Country': 'SB',
#   'Lat': -8.77,
#   'Lng': 160.7,
#   'Max Temp': 86.4,
#   'Humidity': 64,
#   'Cloudiness': 69,
#   'Wind Speed': 2.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Smidovich',
#   'Country': 'RU',
#   'Lat': 48.6,
#   'Lng': 133.82,
#   'Max Temp': 62.02,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 9.69,
#   'Current Description': 'light rain'},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 8.37,
#   'Current Description': 'clear sky'},
#  {'City': 'Khadzhalmakhi',
#   'Country': 'RU',
#   'Lat': 42.42,
#   'Lng': 47.18,
#   'Max Temp': 64.4,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 72,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds'},
#  {'City': 'Guilin',
#   'Country': 'CN',
#   'Lat': 25.28,
#   'Lng': 110.29,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.68,
#   'Max Temp': 46.8,
#   'Humidity': 72,
#   'Cloudiness': 99,
#   'Wind Speed': 13.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kayerkan',
#   'Country': 'RU',
#   'Lat': 69.35,
#   'Lng': 87.76,
#   'Max Temp': 55.4,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 4.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Aguia Branca',
#   'Country': 'BR',
#   'Lat': -18.98,
#   'Lng': -40.74,
#   'Max Temp': 70.77,
#   'Humidity': 86,
#   'Cloudiness': 55,
#   'Wind Speed': 2.73,
#   'Current Description': 'broken clouds'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 55.4,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 49.12,
#   'Humidity': 86,
#   'Cloudiness': 64,
#   'Wind Speed': 6.49,
#   'Current Description': 'light rain'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 54,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Snina',
#   'Country': 'SK',
#   'Lat': 48.99,
#   'Lng': 22.15,
#   'Max Temp': 62.01,
#   'Humidity': 94,
#   'Cloudiness': 51,
#   'Wind Speed': 2.84,
#   'Current Description': 'broken clouds'},
#  {'City': 'Shahrud',
#   'Country': 'IR',
#   'Lat': 36.42,
#   'Lng': 54.98,
#   'Max Temp': 63.25,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 11.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 64.4,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Moses Lake',
#   'Country': 'US',
#   'Lat': 47.13,
#   'Lng': -119.28,
#   'Max Temp': 102.2,
#   'Humidity': 18,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Current Description': 'clear sky'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 91.4,
#   'Humidity': 62,
#   'Cloudiness': 5,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Hovd',
#   'Country': 'MN',
#   'Lat': 48.01,
#   'Lng': 91.64,
#   'Max Temp': 59.99,
#   'Humidity': 64,
#   'Cloudiness': 14,
#   'Wind Speed': 0.27,
#   'Current Description': 'few clouds'},
#  {'City': 'Nagato',
#   'Country': 'JP',
#   'Lat': 34.38,
#   'Lng': 131.2,
#   'Max Temp': 84.2,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Current Description': 'few clouds'},
#  {'City': 'Grants Pass',
#   'Country': 'US',
#   'Lat': 42.44,
#   'Lng': -123.33,
#   'Max Temp': 96.8,
#   'Humidity': 16,
#   'Cloudiness': 1,
#   'Wind Speed': 6.35,
#   'Current Description': 'clear sky'},
#  {'City': 'Birao',
#   'Country': 'CF',
#   'Lat': 10.28,
#   'Lng': 22.79,
#   'Max Temp': 72.32,
#   'Humidity': 96,
#   'Cloudiness': 97,
#   'Wind Speed': 3.67,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 84.2,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jasper',
#   'Country': 'US',
#   'Lat': 37.2,
#   'Lng': -94.35,
#   'Max Temp': 87.8,
#   'Humidity': 43,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds'},
#  {'City': 'Puerto Escondido',
#   'Country': 'MX',
#   'Lat': 15.85,
#   'Lng': -97.07,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 4.74,
#   'Current Description': 'moderate rain'},
#  {'City': 'Hazorasp',
#   'Country': 'UZ',
#   'Lat': 41.32,
#   'Lng': 61.07,
#   'Max Temp': 62.6,
#   'Humidity': 63,
#   'Cloudiness': 2,
#   'Wind Speed': 6.93,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Augustin',
#   'Country': 'CA',
#   'Lat': 51.23,
#   'Lng': -58.65,
#   'Max Temp': 61.05,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 10.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Concordia',
#   'Country': 'AR',
#   'Lat': -31.39,
#   'Lng': -58.02,
#   'Max Temp': 53.01,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 4.72,
#   'Current Description': 'clear sky'},
#  {'City': 'Abashiri',
#   'Country': 'JP',
#   'Lat': 44.02,
#   'Lng': 144.27,
#   'Max Temp': 64.99,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Current Description': 'broken clouds'},
#  {'City': 'Gladstone',
#   'Country': 'AU',
#   'Lat': -23.85,
#   'Lng': 151.25,
#   'Max Temp': 66.2,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'The Valley',
#   'Country': 'AI',
#   'Lat': 18.22,
#   'Lng': -63.06,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Current Description': 'shower rain'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 51.8,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 8.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Miranda',
#   'Country': 'CO',
#   'Lat': 3.25,
#   'Lng': -76.23,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nyagan',
#   'Country': 'RU',
#   'Lat': 62.14,
#   'Lng': 65.39,
#   'Max Temp': 52.59,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.12,
#   'Lng': 81.12,
#   'Max Temp': 79.48,
#   'Humidity': 83,
#   'Cloudiness': 57,
#   'Wind Speed': 14.12,
#   'Current Description': 'broken clouds'},
#  {'City': 'Granville',
#   'Country': 'AU',
#   'Lat': -33.83,
#   'Lng': 151.02,
#   'Max Temp': 63,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vilyuysk',
#   'Country': 'RU',
#   'Lat': 63.76,
#   'Lng': 121.62,
#   'Max Temp': 55.63,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 4.32,
#   'Current Description': 'clear sky'},
#  {'City': 'Filingue',
#   'Country': 'NE',
#   'Lat': 14.35,
#   'Lng': 3.32,
#   'Max Temp': 87.8,
#   'Humidity': 53,
#   'Cloudiness': 91,
#   'Wind Speed': 16.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 71.78,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.11,
#   'Current Description': 'light rain'},
#  {'City': 'Santa Rosa',
#   'Country': 'PH',
#   'Lat': 14.31,
#   'Lng': 121.11,
#   'Max Temp': 84,
#   'Humidity': 88,
#   'Cloudiness': 95,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namatanai',
#   'Country': 'PG',
#   'Lat': -3.67,
#   'Lng': 152.43,
#   'Max Temp': 83.62,
#   'Humidity': 70,
#   'Cloudiness': 3,
#   'Wind Speed': 9.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Jacqueville',
#   'Country': 'CI',
#   'Lat': 5.21,
#   'Lng': -4.41,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 86,
#   'Humidity': 79,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'light rain'},
#  {'City': 'Kupino',
#   'Country': 'RU',
#   'Lat': 54.37,
#   'Lng': 77.3,
#   'Max Temp': 57.83,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 6.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 42.12,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 11.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Anloga',
#   'Country': 'GH',
#   'Lat': 5.79,
#   'Lng': 0.9,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mbandaka',
#   'Country': 'CD',
#   'Lat': 0.05,
#   'Lng': 18.26,
#   'Max Temp': 71.11,
#   'Humidity': 91,
#   'Cloudiness': 65,
#   'Wind Speed': 2.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Fez',
#   'Country': 'MA',
#   'Lat': 34.04,
#   'Lng': -5,
#   'Max Temp': 73.4,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Jumla',
#   'Country': 'NP',
#   'Lat': 29.27,
#   'Lng': 82.18,
#   'Max Temp': 61.92,
#   'Humidity': 70,
#   'Cloudiness': 56,
#   'Wind Speed': 0.81,
#   'Current Description': 'broken clouds'},
#  {'City': 'Boende',
#   'Country': 'CD',
#   'Lat': -0.22,
#   'Lng': 20.87,
#   'Max Temp': 73.54,
#   'Humidity': 93,
#   'Cloudiness': 79,
#   'Wind Speed': 1.32,
#   'Current Description': 'broken clouds'},
#  {'City': 'Antofagasta',
#   'Country': 'CL',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 57.2,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': 45.23,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0.85,
#   'Current Description': 'light rain'},
#  {'City': 'Yerbogachen',
#   'Country': 'RU',
#   'Lat': 61.28,
#   'Lng': 108.01,
#   'Max Temp': 56.39,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 1.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 50.94,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 0.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.98,
#   'Max Temp': 74.21,
#   'Humidity': 90,
#   'Cloudiness': 87,
#   'Wind Speed': 23.42,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Petrolina',
#   'Country': 'BR',
#   'Lat': -9.4,
#   'Lng': -40.5,
#   'Max Temp': 77.56,
#   'Humidity': 49,
#   'Cloudiness': 2,
#   'Wind Speed': 19.89,
#   'Current Description': 'clear sky'},
#  {'City': 'Penzance',
#   'Country': 'GB',
#   'Lat': 50.12,
#   'Lng': -5.54,
#   'Max Temp': 62.6,
#   'Humidity': 93,
#   'Cloudiness': 38,
#   'Wind Speed': 13.87,
#   'Current Description': 'light rain'},
#  {'City': 'Solnechnyy',
#   'Country': 'RU',
#   'Lat': 50.72,
#   'Lng': 136.63,
#   'Max Temp': 56.43,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.68,
#   'Current Description': 'light rain'},
#  {'City': 'Manoel Urbano',
#   'Country': 'BR',
#   'Lat': -8.84,
#   'Lng': -69.26,
#   'Max Temp': 83.86,
#   'Humidity': 51,
#   'Cloudiness': 53,
#   'Wind Speed': 2.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ravar',
#   'Country': 'IR',
#   'Lat': 31.27,
#   'Lng': 56.81,
#   'Max Temp': 79.05,
#   'Humidity': 26,
#   'Cloudiness': 30,
#   'Wind Speed': 6.15,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5,
#   'Lng': -165.41,
#   'Max Temp': 69.01,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 19.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Thunder Bay',
#   'Country': 'CA',
#   'Lat': 48.4,
#   'Lng': -89.32,
#   'Max Temp': 73.4,
#   'Humidity': 38,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Description': 'broken clouds'},
#  {'City': 'Oksfjord',
#   'Country': 'NO',
#   'Lat': 70.24,
#   'Lng': 22.35,
#   'Max Temp': 46.4,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 15.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pochutla',
#   'Country': 'MX',
#   'Lat': 15.74,
#   'Lng': -96.47,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 8.19,
#   'Current Description': 'light rain'},
#  {'City': 'Chapais',
#   'Country': 'CA',
#   'Lat': 49.78,
#   'Lng': -74.85,
#   'Max Temp': 57.2,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sulangan',
#   'Country': 'PH',
#   'Lat': 11.14,
#   'Lng': 123.72,
#   'Max Temp': 83.23,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 5.84,
#   'Current Description': 'light rain'},
#  {'City': 'Kedgwick',
#   'Country': 'CA',
#   'Lat': 47.64,
#   'Lng': -67.34,
#   'Max Temp': 59.88,
#   'Humidity': 96,
#   'Cloudiness': 21,
#   'Wind Speed': 4.38,
#   'Current Description': 'few clouds'},
#  {'City': 'Barra',
#   'Country': 'BR',
#   'Lat': -11.09,
#   'Lng': -43.14,
#   'Max Temp': 78.82,
#   'Humidity': 50,
#   'Cloudiness': 7,
#   'Wind Speed': 14.58,
#   'Current Description': 'clear sky'},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.02,
#   'Lng': 147.27,
#   'Max Temp': 83.01,
#   'Humidity': 78,
#   'Cloudiness': 10,
#   'Wind Speed': 9.35,
#   'Current Description': 'light rain'},
#  {'City': 'San Andres',
#   'Country': 'CO',
#   'Lat': 12.58,
#   'Lng': -81.7,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Current Description': 'broken clouds'},
#  {'City': 'Akyab',
#   'Country': 'MM',
#   'Lat': 20.15,
#   'Lng': 92.9,
#   'Max Temp': 80.83,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 14.52,
#   'Current Description': 'moderate rain'},
#  {'City': 'Laela',
#   'Country': 'TZ',
#   'Lat': -8.57,
#   'Lng': 32.05,
#   'Max Temp': 57.06,
#   'Humidity': 62,
#   'Cloudiness': 51,
#   'Wind Speed': 2.44,
#   'Current Description': 'broken clouds'},
#  {'City': 'Anadyr',
#   'Country': 'RU',
#   'Lat': 64.75,
#   'Lng': 177.48,
#   'Max Temp': 55.4,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 13.42,
#   'Current Description': 'few clouds'},
#  {'City': 'Jiutai',
#   'Country': 'CN',
#   'Lat': 44.15,
#   'Lng': 125.83,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 13.42,
#   'Current Description': 'mist'},
#  {'City': 'Sioux Lookout',
#   'Country': 'CA',
#   'Lat': 50.1,
#   'Lng': -91.92,
#   'Max Temp': 69.8,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bogomila',
#   'Country': 'MK',
#   'Lat': 41.59,
#   'Lng': 21.47,
#   'Max Temp': 66.2,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 1.48,
#   'Current Description': 'few clouds'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 58.26,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 10.74,
#   'Current Description': 'clear sky'},
#  {'City': 'Kamien Pomorski',
#   'Country': 'PL',
#   'Lat': 53.97,
#   'Lng': 14.77,
#   'Max Temp': 71.01,
#   'Humidity': 68,
#   'Cloudiness': 5,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 55.38,
#   'Humidity': 64,
#   'Cloudiness': 46,
#   'Wind Speed': 26.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 60.69,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Current Description': 'light rain'},
#  {'City': 'Waddan',
#   'Country': 'LY',
#   'Lat': 29.16,
#   'Lng': 16.14,
#   'Max Temp': 81.66,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Narrabri',
#   'Country': 'AU',
#   'Lat': -30.32,
#   'Lng': 149.78,
#   'Max Temp': 59,
#   'Humidity': 54,
#   'Cloudiness': 21,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Berdigestyakh',
#   'Country': 'RU',
#   'Lat': 62.1,
#   'Lng': 126.7,
#   'Max Temp': 54.19,
#   'Humidity': 62,
#   'Cloudiness': 42,
# ...
#  {'City': 'Chokwe',
#   'Country': 'MZ',
#   'Lat': -24.53,
#   'Lng': 32.98,
#   'Max Temp': 61.84,
#   'Humidity': 89,
#   'Cloudiness': 3,
#   'Wind Speed': 8.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Kermanshah',
#   'Country': 'IR',
#   'Lat': 34.31,
#   'Lng': 47.06,
#   'Max Temp': 68,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Lipovtsy',
#   'Country': 'RU',
#   'Lat': 44.2,
#   'Lng': 131.72,
#   'Max Temp': 75.47,
#   'Humidity': 86,
#   'Cloudiness': 89,
#   'Wind Speed': 13.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nizhniy Chir',
#   'Country': 'RU',
#   'Lat': 48.36,
#   'Lng': 43.09,
#   'Max Temp': 68.02,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 8.43,
#   'Current Description': 'clear sky'},
#  {'City': 'Lubao',
#   'Country': 'PH',
#   'Lat': 14.92,
#   'Lng': 120.55,
#   'Max Temp': 84,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cam Ranh',
#   'Country': 'VN',
#   'Lat': 11.92,
#   'Lng': 109.16,
#   'Max Temp': 82.4,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Severodvinsk',
#   'Country': 'RU',
#   'Lat': 64.56,
#   'Lng': 39.83,
#   'Max Temp': 41,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 10.76,
#   'Current Description': 'few clouds'},
#  {'City': 'Tabriz',
#   'Country': 'IR',
#   'Lat': 38.08,
#   'Lng': 46.29,
#   'Max Temp': 62.6,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 20.8,
#   'Current Description': 'few clouds'},
#  {'City': 'Labelle',
#   'Country': 'US',
#   'Lat': 26.76,
#   'Lng': -81.44,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Urucara',
#   'Country': 'BR',
#   'Lat': -2.54,
#   'Lng': -57.76,
#   'Max Temp': 86.34,
#   'Humidity': 41,
#   'Cloudiness': 50,
#   'Wind Speed': 1.77,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Krasnogorsk',
#   'Country': 'RU',
#   'Lat': 55.82,
#   'Lng': 37.32,
#   'Max Temp': 59,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Letovice',
#   'Country': 'CZ',
#   'Lat': 49.55,
#   'Lng': 16.57,
#   'Max Temp': 66,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Lat': 8,
#   'Lng': 124.29,
#   'Max Temp': 78.01,
#   'Humidity': 84,
#   'Cloudiness': 86,
#   'Wind Speed': 8.01,
#   'Current Description': 'light rain'},
#  {'City': 'Stromness',
#   'Country': 'GB',
#   'Lat': 58.97,
#   'Lng': -3.3,
#   'Max Temp': 55.4,
#   'Humidity': 100,
#   'Cloudiness': 91,
#   'Wind Speed': 11.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mitsamiouli',
#   'Country': 'KM',
#   'Lat': -11.38,
#   'Lng': 43.28,
#   'Max Temp': 76.37,
#   'Humidity': 74,
#   'Cloudiness': 42,
#   'Wind Speed': 6.29,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Narino',
#   'Country': 'CO',
#   'Lat': -3.77,
#   'Lng': -70.38,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hobyo',
#   'Country': 'SO',
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 76.03,
#   'Humidity': 70,
#   'Cloudiness': 54,
#   'Wind Speed': 22.64,
#   'Current Description': 'broken clouds'},
#  {'City': 'Zarechnyy',
#   'Country': 'RU',
#   'Lat': 53.2,
#   'Lng': 45.19,
#   'Max Temp': 55,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 3.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Sobolevo',
#   'Country': 'RU',
#   'Lat': 54.43,
#   'Lng': 31.9,
#   'Max Temp': 57.88,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 5.03,
#   'Current Description': 'clear sky'},
#  {'City': 'Worthington',
#   'Country': 'US',
#   'Lat': 40.09,
#   'Lng': -83.02,
#   'Max Temp': 81,
#   'Humidity': 47,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nehe',
#   'Country': 'CN',
#   'Lat': 48.48,
#   'Lng': 124.83,
#   'Max Temp': 64.49,
#   'Humidity': 88,
#   'Cloudiness': 93,
#   'Wind Speed': 15.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ha Tinh',
#   'Country': 'VN',
#   'Lat': 18.33,
#   'Lng': 105.9,
#   'Max Temp': 78.48,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3.02,
#   'Current Description': 'light rain'},
#  {'City': 'Xai-Xai',
#   'Country': 'MZ',
#   'Lat': -25.05,
#   'Lng': 33.64,
#   'Max Temp': 61.57,
#   'Humidity': 92,
#   'Cloudiness': 3,
#   'Wind Speed': 9.69,
#   'Current Description': 'clear sky'},
#  {'City': 'Along',
#   'Country': 'IN',
#   'Lat': 28.17,
#   'Lng': 94.77,
#   'Max Temp': 73.18,
#   'Humidity': 89,
#   'Cloudiness': 70,
#   'Wind Speed': 1.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'haze'},
#  {'City': 'Juneau',
#   'Country': 'US',
#   'Lat': 58.3,
#   'Lng': -134.42,
#   'Max Temp': 62.01,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'moderate rain'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.43,
#   'Lng': 26.4,
#   'Max Temp': 61,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 4.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Mattru',
#   'Country': 'SL',
#   'Lat': 7.62,
#   'Lng': -11.83,
#   'Max Temp': 73.49,
#   'Humidity': 89,
#   'Cloudiness': 96,
#   'Wind Speed': 2.73,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mount Darwin',
#   'Country': 'ZW',
#   'Lat': -16.77,
#   'Lng': 31.58,
#   'Max Temp': 57.88,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 6.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Chicama',
#   'Country': 'PE',
#   'Lat': -7.84,
#   'Lng': -79.15,
#   'Max Temp': 60.46,
#   'Humidity': 83,
#   'Cloudiness': 17,
#   'Wind Speed': 8.48,
#   'Current Description': 'few clouds'},
#  {'City': 'Llata',
#   'Country': 'PE',
#   'Lat': -9.42,
#   'Lng': -76.78,
#   'Max Temp': 50.5,
#   'Humidity': 74,
#   'Cloudiness': 38,
#   'Wind Speed': 4.05,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tecoanapa',
#   'Country': 'MX',
#   'Lat': 16.52,
#   'Lng': -98.75,
#   'Max Temp': 79.14,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.35,
#   'Current Description': 'moderate rain'},
#  {'City': 'Adeje',
#   'Country': 'ES',
#   'Lat': 28.12,
#   'Lng': -16.73,
#   'Max Temp': 77,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 18.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Shache',
#   'Country': 'CN',
#   'Lat': 38.42,
#   'Lng': 77.24,
#   'Max Temp': 65.14,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky'},
#  {'City': 'Oranjemund',
#   'Country': 'NA',
#   'Lat': -28.55,
#   'Lng': 16.43,
#   'Max Temp': 55.47,
#   'Humidity': 77,
#   'Cloudiness': 73,
#   'Wind Speed': 7.36,
#   'Current Description': 'light rain'},
#  {'City': 'Lagdo',
#   'Country': 'CM',
#   'Lat': 9.05,
#   'Lng': 13.73,
#   'Max Temp': 73.35,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.04,
#   'Current Description': 'moderate rain'},
#  {'City': 'Waitati',
#   'Country': 'NZ',
#   'Lat': -45.75,
#   'Lng': 170.57,
#   'Max Temp': 51.01,
#   'Humidity': 71,
#   'Cloudiness': 62,
#   'Wind Speed': 42.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kapoeta',
#   'Country': 'SS',
#   'Lat': 4.77,
#   'Lng': 33.59,
#   'Max Temp': 74.34,
#   'Humidity': 73,
#   'Cloudiness': 58,
#   'Wind Speed': 4.56,
#   'Current Description': 'broken clouds'},
#  {'City': 'Freetown',
#   'Country': 'SL',
#   'Lat': 8.48,
#   'Lng': -13.23,
#   'Max Temp': 75.79,
#   'Humidity': 89,
#   'Cloudiness': 91,
#   'Wind Speed': 8.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Noumea',
#   'Country': 'NC',
#   'Lat': -22.28,
#   'Lng': 166.46,
#   'Max Temp': 73,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Damara',
#   'Country': 'CF',
#   'Lat': 4.96,
#   'Lng': 18.7,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Salvador',
#   'Country': 'SV',
#   'Lat': 13.83,
#   'Lng': -88.92,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Teya',
#   'Country': 'RU',
#   'Lat': 60.38,
#   'Lng': 92.63,
#   'Max Temp': 54.18,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 2.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Oriximina',
#   'Country': 'BR',
#   'Lat': -1.77,
#   'Lng': -55.87,
#   'Max Temp': 85.68,
#   'Humidity': 45,
#   'Cloudiness': 36,
#   'Wind Speed': 3.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Doha',
#   'Country': 'QA',
#   'Lat': 25.29,
#   'Lng': 51.53,
#   'Max Temp': 93.2,
#   'Humidity': 44,
#   'Cloudiness': 39,
#   'Wind Speed': 5.82,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Allen',
#   'Country': 'US',
#   'Lat': 41.07,
#   'Lng': -85.01,
#   'Max Temp': 78.8,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Santo Domingo',
#   'Country': 'DO',
#   'Lat': 18.5,
#   'Lng': -69.99,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Escarcega',
#   'Country': 'MX',
#   'Lat': 18.61,
#   'Lng': -90.75,
#   'Max Temp': 78.62,
#   'Humidity': 90,
#   'Cloudiness': 95,
#   'Wind Speed': 4.12,
#   'Current Description': 'moderate rain'},
#  {'City': 'Mildura',
#   'Country': 'AU',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 57,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Teteven',
#   'Country': 'BG',
#   'Lat': 42.92,
#   'Lng': 24.27,
#   'Max Temp': 64.99,
#   'Humidity': 65,
#   'Cloudiness': 67,
#   'Wind Speed': 5.12,
#   'Current Description': 'broken clouds'},
#  {'City': 'Zeya',
#   'Country': 'RU',
#   'Lat': 53.75,
#   'Lng': 127.27,
#   'Max Temp': 52.56,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 6.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.71,
#   'Lng': -39.25,
#   'Max Temp': 72.55,
#   'Humidity': 84,
#   'Cloudiness': 2,
#   'Wind Speed': 6.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Pangnirtung',
#   'Country': 'CA',
#   'Lat': 66.15,
#   'Lng': -65.71,
#   'Max Temp': 60.89,
#   'Humidity': 58,
#   'Cloudiness': 87,
#   'Wind Speed': 1.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Norfolk',
#   'Country': 'US',
#   'Lat': 42.17,
#   'Lng': -71.25,
#   'Max Temp': 71.01,
#   'Humidity': 72,
#   'Cloudiness': 9,
#   'Wind Speed': 9.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Gigmoto',
#   'Country': 'PH',
#   'Lat': 13.78,
#   'Lng': 124.39,
#   'Max Temp': 83.23,
#   'Humidity': 76,
#   'Cloudiness': 93,
#   'Wind Speed': 1.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hervey Bay',
#   'Country': 'AU',
#   'Lat': -25.3,
#   'Lng': 152.85,
#   'Max Temp': 66.2,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12,
#   'Current Description': 'clear sky'},
#  {'City': 'Mataram',
#   'Country': 'ID',
#   'Lat': -8.58,
#   'Lng': 116.12,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mumford',
#   'Country': 'GH',
#   'Lat': 5.26,
#   'Lng': -0.76,
#   'Max Temp': 74.1,
#   'Humidity': 89,
#   'Cloudiness': 22,
#   'Wind Speed': 12.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Novikovo',
#   'Country': 'RU',
#   'Lat': 51.15,
#   'Lng': 37.89,
#   'Max Temp': 63.45,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 6.55,
#   'Current Description': 'clear sky'},
#  {'City': 'Cap Malheureux',
#   'Country': 'MU',
#   'Lat': -19.98,
#   'Lng': 57.61,
#   'Max Temp': 72,
#   'Humidity': 70,
#   'Cloudiness': 3,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'Severnyy',
#   'Country': 'RU',
#   'Lat': 50.68,
#   'Lng': 36.55,
#   'Max Temp': 66.2,
#   'Humidity': 68,
#   'Cloudiness': 3,
#   'Wind Speed': 8.95,
#   'Current Description': 'clear sky'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.86,
#   'Lng': 29.09,
#   'Max Temp': 47.79,
#   'Humidity': 75,
#   'Cloudiness': 97,
#   'Wind Speed': 17.63,
#   'Current Description': 'light rain'},
#  {'City': 'Bucerias',
#   'Country': 'MX',
#   'Lat': 20.75,
#   'Lng': -105.33,
#   'Max Temp': 86,
#   'Humidity': 79,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kiruna',
#   'Country': 'SE',
#   'Lat': 67.86,
#   'Lng': 20.23,
#   'Max Temp': 42.8,
#   'Humidity': 81,
#   'Cloudiness': 95,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Minas',
#   'Country': 'UY',
#   'Lat': -34.38,
#   'Lng': -55.24,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Zhanaozen',
#   'Country': 'KZ',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 62.13,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 6.8,
#   'Current Description': 'clear sky'},
#  {'City': 'New Iberia',
#   'Country': 'US',
#   'Lat': 30,
#   'Lng': -91.82,
#   'Max Temp': 89.6,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Current Description': 'clear sky'},
#  {'City': 'Cabedelo',
#   'Country': 'BR',
#   'Lat': -6.98,
#   'Lng': -34.83,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Current Description': 'few clouds'},
#  {'City': 'Kokstad',
#   'Country': 'ZA',
#   'Lat': -30.55,
#   'Lng': 29.42,
#   'Max Temp': 49.86,
#   'Humidity': 41,
#   'Cloudiness': 7,
#   'Wind Speed': 10.92,
#   'Current Description': 'clear sky'},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.52,
#   'Lng': -13.05,
#   'Max Temp': 97.25,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 16.31,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint Anthony',
#   'Country': 'US',
#   'Lat': 45.02,
#   'Lng': -93.22,
#   'Max Temp': 75.99,
#   'Humidity': 41,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Current Description': 'few clouds'},
#  {'City': 'Miyako',
#   'Country': 'JP',
#   'Lat': 39.64,
#   'Lng': 141.95,
#   'Max Temp': 77.04,
#   'Humidity': 76,
#   'Cloudiness': 77,
#   'Wind Speed': 4.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'San Angelo',
#   'Country': 'US',
#   'Lat': 31.46,
#   'Lng': -100.44,
#   'Max Temp': 93,
#   'Humidity': 34,
#   'Cloudiness': 87,
#   'Wind Speed': 1.99,
#   'Current Description': 'light rain'},
#  {'City': 'Kysyl-Syr',
#   'Country': 'RU',
#   'Lat': 63.9,
#   'Lng': 122.76,
#   'Max Temp': 56.37,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 4.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Eureka',
#   'Country': 'US',
#   'Lat': 40.8,
#   'Lng': -124.16,
#   'Max Temp': 69.01,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Lat': -31.95,
#   'Lng': 141.43,
#   'Max Temp': 53.6,
#   'Humidity': 66,
#   'Cloudiness': 2,
#   'Wind Speed': 9.98,
#   'Current Description': 'clear sky'},
#  {'City': 'Rudbar',
#   'Country': 'AF',
#   'Lat': 30.15,
#   'Lng': 62.6,
#   'Max Temp': 75.52,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 9.62,
#   'Current Description': 'clear sky'},
#  {'City': 'Sterling',
#   'Country': 'US',
#   'Lat': 39.01,
#   'Lng': -77.43,
#   'Max Temp': 78.01,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Bawku',
#   'Country': 'GH',
#   'Lat': 11.06,
#   'Lng': -0.24,
#   'Max Temp': 77.99,
#   'Humidity': 80,
#   'Cloudiness': 58,
#   'Wind Speed': 4.7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Garowe',
#   'Country': 'SO',
#   'Lat': 8.41,
#   'Lng': 48.48,
#   'Max Temp': 73.98,
#   'Humidity': 63,
#   'Cloudiness': 66,
#   'Wind Speed': 28.86,
#   'Current Description': 'broken clouds'},
#  {'City': 'Cameta',
#   'Country': 'BR',
#   'Lat': -2.24,
#   'Lng': -49.5,
#   'Max Temp': 83.21,
#   'Humidity': 73,
#   'Cloudiness': 76,
#   'Wind Speed': 8.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kokoda',
#   'Country': 'PG',
#   'Lat': -8.88,
#   'Lng': 147.74,
#   'Max Temp': 78.19,
#   'Humidity': 65,
#   'Cloudiness': 81,
#   'Wind Speed': 3.27,
#   'Current Description': 'broken clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                           City Country    Lat     Lng  Max Temp  Humidity  \
# 0               Rio De Janeiro      BR -22.90  -43.21     75.20        78
# 1    Santa Isabel Do Rio Negro      BR  -0.41  -65.02     78.06        83
# 2                      Honiara      SB  -9.43  159.95     87.80        70
# 3                     Misratah      LY  32.38   15.09     82.89        57
# 4                       Torbay      CA  47.67  -52.73     66.00        68
# ..                         ...     ...    ...     ...       ...       ...
# 713                   Sterling      US  39.01  -77.43     78.01        78
# 714                      Bawku      GH  11.06   -0.24     77.99        80
# 715                     Garowe      SO   8.41   48.48     73.98        63
# 716                     Cameta      BR  -2.24  -49.50     83.21        73
# 717                     Kokoda      PG  -8.88  147.74     78.19        65
#
#      Cloudiness  Wind Speed Current Description
# 0           100       13.87       moderate rain
# 1            83        1.43          light rain
# 2            20        6.93          few clouds
# 3             0        8.50           clear sky
# 4            90       13.87     overcast clouds
# ..          ...         ...                 ...
# 713           1        5.82           clear sky
# 714          58        4.70       broken clouds
# 715          66       28.86       broken clouds
# 716          76        8.68       broken clouds
# 717          81        3.27       broken clouds
#
# [718 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
